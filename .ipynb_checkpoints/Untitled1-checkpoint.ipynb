# %%
#String index
a="Computer Lab"
print(a[0])
print(a[:7])#it starts from 0
print(a[1:])# starts from 1 index to end position
print(a.capitalize())# Converts first letter capital of string
print(a.casefold())#capital to small
print(a.count("C"))#count occurence of letter in string
print(a.endswith("ab"))#check if string ends with specific value or not.
print(a.startswith("Co"))
#print(a.expandtabs(20)) error
print(a.find("L"))#it find index position otherwise return -1
#it allow us to put values in string according to its index position
#b="I Live in "+[0]
#b.format('pune')//error
#print(b)
print(a.index("Lab"))#It gives index position of a letter or its sequence.space Not consider
print(a.isalnum())
a="abc"
print(a.isdigit())
#identifier-It helps you to check whether U can fun name,class or variable name 
#use the value for these
str="print"
print(a.islower())
print(a.isnumeric())
print(a.isprintable())#a="2\tab" not allowed for printing returns false
#isspace()-It returns true only if string is blank a=" "
#istitle()-It Returns true if string contains First letter in Upper case means title.
str="Moniter"
print(str.istitle())
#isupper()-Checks whether all letters is in capital
a=" 123 "
print(a.join("ABC"))
print(a.join(['5','b','5']))
a="abc"
print(a.rjust(7,"R"))# add letters to the string from right side.7-Total letters
#ljust
#lstrip-It will cut the string from left side.
a="666abc666"
print(a.lstrip("666"))
a="Computer is electronic, device"
print(a.partition("is"))# spilts the string.
print(a.rpartition(","))#partition  from right side.
#replace string with given values
a=("1,2,3,4")
print(a.replace(',','&'))#Replace string with given value.
print(a.split("&"))
print(a.replace(',','&',1))
a="This is pune"
print(a.rfind('i'))#find letter from right side but prints position from left side
#rindex()-It will print index position from right side.
print(a.rjust(15,'9'))
str="This is pune\nWelcome Here\nThanks"
print(str.splitlines())
print(str.swapcase())#swap small to capital and vise a versa
str="pune"
print(str.zfill(7))
print(str.title())
print(str.upper())
