# %% [markdown]
# # What is Python ????????
# Python is object oriented language.
# Python is an interpreted language
# The interpreter provides an interactive
# environment to play with the language
# Results of expressions are printed on the
# screen
#
# There are 2 Versions of python
# Python 2 and
# Python 3
# Python 2 is scheduled to retired in 2020 due to its limitation so Python 3 is widely used now in most of the applications.
#
#
#
# # COMMENTS
#  Comments are used to make code more understandable for person who is reading it.
#  In python there are two approach for comments.
#  ## Multi Line
#   Block of code enclosed by (''' ''') or (""" """) will be treated as multiline comments.
#  ## Single Line
#    #(hash) anything written after the # sign will be treated as sinle line comment.
#
# # INDENTATION
#
#  Python has strict way of indedntation.Python forces programmer to write  code in proper way.
#     Four blank spaces or Tab are used as the indentation in python.

# %% [markdown]
# # Data types in Python
# ### Integers
# integer – the equivalent of
# a C long
# Long Integer – an
# unbounded integer value.

# %%
a=5
print(a)
# Out:
# 5

# %% [markdown]
# ### Float
# used for decimal values
# int(x) converts x to an
# integer
# float(x) converts x to a  floating point
# The interpreter shows  a lot of digits

# %%
a=5
print(a)
b=6.77
print(b)
print(float(a))
print(int(b))
# Out:
# 5
# 6.77
# 5.0
# 6

# %% [markdown]
# ### Strings
# Strings are immutable
# There is no char type like
# in C++ or Java

# %%
c='hello'
print(c)
d='world'
print(d)
print(c+d)
# Out:
# hello
# world
# helloworld

# %% [markdown]
# ## Booleans
# 0 and None are false
# Everything else is true
# True and False are aliases for 1 and 0 respectively
#
# Compound boolean expressions consists of
# and and or return one of the elements in the  expression
# Note that when None is returned the interpreter
# does not print anything

# %%
print(7==7)
print(7=='1')
# Out:
# True
# False

# %% [markdown]
# # VARIABLE ASSIGNMENT
#     x=20
#     '='(equal to operator) is used for variable assignment where value on right is assingnrd to the left variable of the operator.
#
# ### MULTIPLE VARIABLE ASSIGNMENT
#     a=b=c=10
#     Here 10 is assigned to the all the values a,b,c.

# %%
#Print function in python is used to display output on screen.
a=9
print('a')
print(2+3)
print(a)
# Out:
# a
# 5
# 9

# %%
x, y, z = 3, 4, 5

# %% [markdown]
# The pythonic way to name variables is to use all lowercase letters and underscores to separate words.
#
# YES
#
# my_height = 58
# my_lat = 40
# my_long = 105
# NO
#
# my height = 58
# MYLONG = 40
# MyLat = 105

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # VARIABLE IDENTIFICATION
#     To know the class or type of variable following command is used
#     type(varible_name) or type(value)

# %%
#type() Function returns the type of the given variable
a=9
type(a)
b='x'
#type(b)

# %% [markdown]
# Good
# print(4 + 5)
# Bad
# print(                       4 + 5)
# You should limit each line of code to 80 characters, though 99 is okay for certain use cases.

# %%
x=input("Enter value  ")
y=input("Enter other value   "  )
print("addition is",x+y)
# Out:
# Enter value  6
# Enter other value   6
# addition is 66

# %% [markdown]
# # TYPE CASTING
#     Every user input is of class string in python. To convert it to the class int we use type casting as follows

# %% [markdown]
# In this quiz, you’ll need to change the types of the input and output data in order to get the result you want.
#
# Calculate and print the total sales for the week from the data provided. Print out a string of the form "This week's total sales: xxx", where xxx will be the actual total of all the numbers. You’ll need to change the type of the input data in order to calculate that total.

# %%
mon_sales = "121"
tues_sales = "105"
wed_sales = "110"
thurs_sales = "98"
fri_sales = "95"
total=int(mon_sales)+int(tues_sales)+int(wed_sales)+int(thurs_sales)+int(fri_sales)
#TODO: Print a string with this format: This week's total sales: xxx
# You will probably need to write some lines of code before the print statement.
print("This week's total sales:",+total)
# Out:
# This week's total sales: 529

# %%
a=(input("Number one is  "))
b=(input("Number two is  "))
print("addition is",a+b)
# Out:
# Number one is  6
# Number two is  6
# addition is 66

# %%
a=int(input("Number one is  "))
b=int(input("Number two is  "))
print("addition is",a+b)
# Out:
# Number one is  6
# Number two is  6
# addition is 12

# %% [markdown]
# My electricity bills for the last three months have been $23, $32 and $64. What is the average monthly electricity bill over the three month period? Write an expression to calculate the mean, and use print() to view the result.

# %%
# Write an expression that calculates the average of 23, 32 and 64.
# Place the expression in this print statement.
print((23+32+64)/3)
# Out:
# 39.666666666666664

# %% [markdown]
# In this quiz you're going to do some calculations for a tiler. Two parts of a floor need tiling. One part is 9 tiles wide by 7 tiles long, the other is 5 tiles wide by 7 tiles long. Tiles come in packages of 6.
#
# How many tiles are needed?
# You buy 17 packages of tiles containing 6 tiles each. How many tiles will be left over?

# %%
# Fill this in with an expression that calculates how many tiles are needed.
print((9*7)+(5*7))

# Fill this in with an expression that calculates how many tiles will be left over.
print((17*6)-(63+35))
# Out:
# 98
# 4

# %% [markdown]
# # OPERATORS
# There are different tpes of operators in the python. They are as follows:
#
# ## ARITHEMATIC OPERATORS
# (+) - addition
#
# (-)- substration
#
# (*) - multiplication
#
# (/) - division
#
# (**) - power or raised to
#
# (//) - floor division(takes first digit of value)
#
# (%) - modulus
#
# Rule for operators is PEDMAS
# parenthesis
# Exponent
# Division
# multiplication
# add
# subb

# %%
print('1.addition is ',a+b,'\n2.subtraction is',a-b,'\n3.multiplication is',a*b,'\n4.division is',a/b,'\n5. a raised to power b is',a**b,'\n6.floor division is',a//b,'\n7. modulo is',a%b)#arithematic
# Out:
# 1.addition is  12
# 2.subtraction is 0
# 3.multiplication is 36
# 4.division is 1.0
# 5. a raised to power b is 46656
# 6.floor division is 1
# 7. modulo is 0

# %% [markdown]
# ## COMPARISION OPERATORS
# (<)- less than
#
# (>)-greater than
#
# (<=)-greater than equal to
#
# (>=)-less than equal to
#
# == - equal to
#
# != - not equal to

# %%
print('less =',a<b,'\n','less equal =',a<=b,'\n','greater =',a>b,'\n','greater equal =',a>=b,'\n','equal to =',a==b,'\n','not equal= ',a!=b)#operators
# Out:
# less = False
#  less equal = True
#  greater = False
#  greater equal = True
#  equal to = True
#  not equal=  False

# %% [markdown]
# ## LOGICAL OPERATOR
# AND - logical and
#
# OR - logical or
#
# NOT - logical not

# %%
print('and_is',a and b,'or_is',a or b,'not_is',not b)
# Out:
# and_is 6 or_is 6 not_is False

# %% [markdown]
# ## ASSIGNMENT OPERATOR
# Assignment operator works as follows:
# a+=2
# this is solved as a=a+2
# These are the assignment oprators
# All the arithematic operators followed by an equal to(=)
#
# =
#
# +=
#
# -=
#
# *=
#
# /=
#
# **=
#
# //=
#
# %=

# %%
a+=2
print(a)
a-=2
print(a)
a*=2
print(a)
a/=2
print(a)
a//=2
print(a)
a**=2
print(a)
a%=2
print(a)
# Out:
# 8
# 6
# 12
# 6.0
# 3.0
# 9.0
# 1.0

# %% [markdown]
# ## MEMBERSHIP OPERATOR
# - IN
# - NOT IN
#
# This operators check whether the element is present or not present into the list.

# %%
 c=input('enter word ')
d=input('check alphabet to serarch in given word ')

print('alphabet present in the given word' ,d in c)
# Out:
# enter word hi
# check alphabet to serarch in given word o
# alphabet present in the given word False

# %% [markdown]
# Try comparison operators in this quiz! This code calculates the population densities of Rio de Janeiro and San Francisco.
#
# Write code to compare these densities. Is the population of San Francisco more dense than that of Rio de Janeiro? Print True if it is and False if not.

# %%
sf_population, sf_area = 864816, 231.89
rio_population, rio_area = 6453682, 486.5

san_francisco_pop_density = sf_population/sf_area
rio_de_janeiro_pop_density = rio_population/rio_area

# Write code that prints True if San Francisco is denser than Rio, and False otherwise
print(san_francisco_pop_density<rio_de_janeiro_pop_density)
# Out:
# True

# %% [markdown]
# You saw that you can change variable types to perform different operations. For example,
#
# "0" + "5"
# provides completely different output than
#
# 0 + 5
# What do you think the below would provide?
#
# "0" + 5
# How about the code here:
#
# 0 + "5"
# Checking your variable types is really important to assure that you are retrieving the results you want when programming.
